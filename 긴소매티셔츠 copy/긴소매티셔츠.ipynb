# %%
import pandas as pd

# %%
df1 = pd.read_csv('긴소매_p1_106711935.csv', encoding='utf-8')
df1
# Out:
#             아이디  리뷰어 등급     작성 날짜                옵션1       옵션2   상품 사이즈  \
# 0           NaN     NaN       NaN                NaN       NaN      NaN
# 1          84**     NaN  24.04.19        민트(20수ver.)  F(44~66)   정사이즈예요
# 2      ewyfG1bz     NaN  24.04.26    스카이블루(세미크롭ver.)  F(44~66)   정사이즈예요
# 3    wlst******     NaN  24.04.25       핑크(세미크롭ver.)  F(44~66)   정사이즈예요
# 4      meoylfeb  상위 10%  24.04.24     아이보리(세미크롭ver.)  F(44~66)   정사이즈예요
# ..          ...     ...       ...                ...       ...      ...
# 995    LoDzVFrW     NaN  24.10.19  아이보리(세미크롭-긴팔ver.)  F(44~66)  생각보다 커요
# 996    jHHpguvK  상위 25%  24.10.19     크림(20수-긴팔ver.)  F(44~66)   정사이즈예요
# 997    VamewyM4     NaN  24.10.19  아이보리(세미크롭-긴팔ver.)  F(44~66)   정사이즈예요
# 998    VamewyM4     NaN  24.10.19    블랙(세미크롭-긴팔ver.)  F(44~66)   정사이즈예요
# 999    ZHDhjoJQ     NaN  24.10.18  버터크림(세미크롭-반팔ver.)  F(44~66)   정사이즈예요
#
#          퀄리티         색감      키   몸무게    사이즈  \
# 0        NaN        NaN    NaN   NaN    NaN
# ...
